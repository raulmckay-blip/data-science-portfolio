# %%
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %%
import pandas as pd

df = pd.DataFrame({
    "week": [1],
    "status": ["ready"]
})

df
# Out:
#    week status
# 0     1  ready

# %% [markdown]
# In this course I may use AI tools to help explain concepts, debug code, and get ideas when I'm stuck.
# I may not submit AI-generated work as my own without understanding it, and I must not use AI to complete graded assignments for me.
