# %% [markdown]
# Summary Table – Chick Weights by Feed Type
#
# | Feed       | Min Weight | Mean Weight | Max Weight |
# |------------|------------|-------------|------------|
# | Horsebean  | 108        | 160.2       | 227        |
# | Linseed    | 141        | 218.8       | 309        |
# | Soybean    | 158        | 246.3       | 329        |
# | Sunflower  | 226        | 322.7       | 423        |
# | Meatmeal   | 153        | 276.9       | 380        |
# | Casein     | 216        | 323.6       | 404        |

# %% [markdown]
# Recommendation:
#
# I would buy Casein feed for the poultry business. It has the highest average weight (323.6 lbs), which means chickens tend to grow heavier overall compared to the other options. Although Sunflower reaches a slightly higher maximum weight (423 lbs), Casein’s mean is still the best and its minimum is also solid. Horsebean and Linseed clearly underperform, so they would not be good investments. Casein offers the most consistent high performance, making it the strongest choice for maximizing business returns.
